# %%
import json

# %%
with open('/home1/pupil/rmf3mc/test_access/ViGIR_CVPR_LLM/data_split/split_zhou_DescribableTextures.json', 'r') as f:
    data = json.load(f)

third_values = ([item[2] for item in data['train']])

print(third_values)
# Out:
# ['banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'banded', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', 'blotchy', '
# ...

# %%
seen = set()
unique_strings = []
for item in third_values:
    if item not in seen:
        unique_strings.append(item)
        seen.add(item)

# %%
print(unique_strings)
# Out:
# ['banded', 'blotchy', 'braided', 'bubbly', 'bumpy', 'chequered', 'cobwebbed', 'cracked', 'crosshatched', 'crystalline', 'dotted', 'fibrous', 'flecked', 'freckled', 'frilly', 'gauzy', 'grid', 'grooved', 'honeycombed', 'interlaced', 'knitted', 'lacelike', 'lined', 'marbled', 'matted', 'meshed', 'paisley', 'perforated', 'pitted', 'pleated', 'polka-dotted', 'porous', 'potholed', 'scaly', 'smeared', 'spiralled', 'sprinkled', 'stained', 'stratified', 'striped', 'studded', 'swirly', 'veined', 'waffled', 'woven', 'wrinkled', 'zigzagged']
