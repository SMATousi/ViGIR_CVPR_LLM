# %%
import ollama 
import os
from tqdm import tqdm
import json
import signal
import argparse
import wandb

import sys

from  utilities import *

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
# sys.argv = [
#     'notebook',  
#     '--modelname', 'llava:7b',
#     '--prompt', 'Is this an offensive meme? Please answer with YES or NO. DO NOT mention the reason:',
#     '--data', 'hateful_memes',
#     '--data_path','/home1/pupil/goowfd/CVPR_2025/hateful_memes/',
#     "--data_samples", 'train.jsonl',
#     "--subset", 'train',
#     '--results_dir', '/home1/pupil/goowfd/CVPR_2025/hateful_memes/results/baselineExp',
#     '--timeout', '20',
#     '--model_unloading'
# ]


# sys.argv = [
#     'notebook',  
#     '--modelname', 'llava:7b',
#     '--prompt', 'Classify the satellite image into one of the following categories: SeaLake, PermanentCrop, River, Residential, Pasture, Industrial, Highway, HerbaceousVegetation, Forest, or AnnualCrop. Provide only the class name as your answer.',
#     '--data', 'eurosat',
#     '--data_path','/home1/pupil/rmf3mc/eurosat/2750/',
#     "--data_samples", '../../data_split/split_zhou_EuroSAT.json',
#     "--subset", 'train',
#     '--results_dir', '/home1/pupil/rmf3mc/eurosat/results/baselineExp',
#     '--timeout', '20',
#     '--model_unloading'
# ]

# %%
parser = argparse.ArgumentParser(description="A script to run V-LLMs on different image classification datasets")

# %%
parser.add_argument("--modelname", type=str, required=True, help="The name of the V-LLM model")
parser.add_argument("--prompt", type=str, required=True, help="The prompt that you want to give to the V-LLM")
parser.add_argument("--data", type=str, required=True, help="Dataset name")
parser.add_argument("--data_path", type=str, required=True, help="Path to the image data dir")
parser.add_argument("--data_samples", type=str, required=True, help="Name of the samples to run on")
parser.add_argument("--subset", type=str, required=True, help="train, test or validation set")
parser.add_argument("--results_dir", type=str, required=True, help="Folder name to save results")
parser.add_argument("--timeout", type=int, default=40, help="time out duration to skip one sample")
parser.add_argument("--model_unloading", action="store_true", help="Enables unloading mode. Every 100 sampels it unloades the model from the GPU to avoid carshing.")

args = parser.parse_args()

# %%
if args.data == 'hateful_memes':
    data ={}
    data_samples_path=os.path.join(args.data_path,args.data_samples)
    images_dir=os.path.join(args.data_path,'img')
    
    with open(data_samples_path, 'r') as file:
        for line in file: 
            record = json.loads(line)
            if record['label']==1:
                data[os.path.join(images_dir,f'{record["img"][4:]}')]={"label":record['label'],"class":'hateful_meme'}
            else:
                data[os.path.join(images_dir,f'{record["img"][4:]}')]={"label":record['label'],"class":'not_hateful_meme'}
                


            
elif args.data == 'eurosat':
    data ={}
    data_samples_path=os.path.join(args.data_path,args.data_samples)
    print(data_samples_path)
    images_dir=os.path.join(args.data_path)
    print(images_dir)
    
    with open(data_samples_path, 'r') as file:
        raw_data = json.load(file)
    
    raw_data=raw_data[args.subset]
    for sample in raw_data:
        #print(sample)
        data[os.path.join(images_dir,sample[0])]={"label":sample[1],"class":sample[2]}
# Out:
# /home1/pupil/rmf3mc/eurosat/2750/../../data_split/split_zhou_EuroSAT.json
# /home1/pupil/rmf3mc/eurosat/2750/
# ['AnnualCrop/AnnualCrop_1381.jpg', 0, 'Annual Crop Land']
# ['AnnualCrop/AnnualCrop_
jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1385.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1697.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1198.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2949.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2162.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1650.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2474.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2756.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_471.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_939.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2427.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2941.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2045.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_69.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2698.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_668.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2096.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1394.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1949.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_654.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1225.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2926.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_225.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2909.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1830.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2376.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_204.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1573.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2684.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_196.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1230.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_107.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2012.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_193.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_55.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_54.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2075.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2048.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2795.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2468.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1744.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_768.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2456.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_493.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2977.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2452.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2855.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1898.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_920.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1028.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1542.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1930.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_102.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_39.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1182.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_498.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1320.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1358.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_972.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1803.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_827.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1761.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_733.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2081.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2396.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_164.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1672.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1465.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1711.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2437.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_472.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1337.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1836.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1142.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2836.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2753.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1881.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_487.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1267.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1883.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1190.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_821.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2787.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2833.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2779.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_142.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_932.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_334.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1403.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2289.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1739.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2403.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2577.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1235.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1214.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1246.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1378.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1994.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_507.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_909.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1928.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2160.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_745.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_315.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2722.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_310.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1281.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2493.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1023.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1630.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_80.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_278.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1629.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2759.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_257.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1596.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_198.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_239.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_867.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_864.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_70.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1561.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1169.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2680.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2469.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2612.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2280.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1890.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_955.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_953.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2037.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2420.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2267.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_1188.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_2526.jpg', 9, 'Sea or Lake']
# ['SeaLake/SeaLake_46.jpg', 9, 'Sea or Lake']

# %%
model_name = args.modelname
results_dir=os.path.join(args.results_dir)
os.makedirs(results_dir, exist_ok=True)

# %%
results_file_name=os.path.join(results_dir,f"{args.data}-{model_name}-{args.subset}.json")
raw_image_info=os.path.join(results_dir,f"{args.data}-{model_name}-{args.subset}-raw_info.json")

# %%
ollama.pull(model_name)

timeout_duration = args.timeout

options= {  # new
            "seed": 123,
            "temperature": 0,
            "num_ctx": 2048, # must be set, otherwise slightly random output
        }

model_labels = {}
prompt = args.prompt
count = 0

# %%
for key,info in tqdm(data.items()):
    print(type(key))
    count = count + 1
    image_path = key

    #disp_img(image_path)
    
    signal.signal(signal.SIGALRM, timeout_handler)
    signal.alarm(timeout_duration)  

    try:
        if args.model_unloading and count % 99 == 0:
            response = ollama.generate(model=model_name, prompt=prompt, images=[image_path], options=options, keep_alive=0)
        else:
            response = ollama.generate(model=model_name, prompt=prompt, images=[image_path], options=options)
    
    except TimeoutException:
        print(f"Prompt for {image_path} took longer than {timeout_duration} seconds. Moving to the next one.")
        label = None
        
    finally:
        signal.alarm(0)  

    model_labels[image_path] = response['response']
# Out:
#   0%|                                          | 0/13500 [00:00<?, ?it/s]
# <class 'str'>
#   0%|                                | 1/13500 [00:00<1:43:58,  2.16it/s]
# <class 'str'>
#   0%|                                | 2/13500 [00:00<1:44:14,  2.16it/s]
# <class 'str'>
#   0%|                                | 3/13500 [00:01<1:32:03,  2.44it/s]
# <class 'str'>
#   0%|                                | 3/13500 [00:01<2:13:20,  1.69it/s]

# %%
with open(results_file_name, 'w') as fp:
    json.dump(model_labels, fp, indent=4)
    
with open(raw_image_info, 'w') as fp:
    json.dump(data, fp, indent=4)
