# %%
import ollama 
import os

# %%
images_path = '../datasets/ignore_dir/hateful_memes/img/'

list_of_image_names = os.listdir(images_path)

# %%
root_path = '/home/macula/SMATousi/CVPR/ViGIR_CVPR_LLM/datasets/ignore_dir/hateful_memes/img'

options= {  # new
            "seed": 123,
            "temperature": 0,
            "num_ctx": 2048, # must be set, otherwise slightly random output
        }
    
for image_name in list_of_image_names:
    
    image_path = os.path.join(root_path, image_name)
    
    prompt = "Is this somehow an offensive meme? Please answer with YES or NO. DO NOT mention the reason: "
#     prompt = "Is this somehow an offensive meme? Please answer with YES or NO: "
#     prompt = "describe this image: "
    
    response = ollama.generate(model='llava:7b', prompt=prompt, images=[image_path], options=options)
    
#     response = ollama.chat(model='llava:34b', messages=[
#       {
#         'role': 'user',
#         'content': prompt,
#       }, 
#     ], options= {  # new
#             "seed": 123,
#             "temperature": 0,
#             "num_ctx": 2048, # must be set, otherwise slightly random output
#         })
    # print(response)
#     print(prompt)
    print("------------------------------------------------------")
    print(image_name)
    print(response['response'])
# Out:
# ------------------------------------------------------
# 01527.png
#  No, the meme is not offensive. It's a humorous take on someone who has been injured and is now trying to run again despite their injury. The humor comes from the exaggerated nature of the person's determination to run, even though they are in pain or have an injury that would normally prevent them from running.
# ------------------------------------------------------
# 01487.png
#  No, this meme is not offensive. It's a humorous take on the idea of forgetting something important, using a sign that says "when you forgot your wallet." The humor comes from the exaggerated reaction of the person holding the sign, which is meant to be funny and relatable for anyone who has ever forgotten an essential item.
# ------------------------------------------------------
# 01349.png
#  No, this meme is not offensive. It features a historical figure and his daughter, and the text is a playful commentary on the relationship between them. The image is respectful and does not contain any inappropriate or disrespectful content.
# ------------------------------------------------------
# 01467.png
#  No.
# ------------------------------------------------------
# 01235.png
#  Yes, this meme is offensive. It uses a stereotype and makes a joke that relies on cultural insensitivity.
# ------------------------------------------------------
# 01634.png
#  No, this meme is not offensive. It features a humorous situation where a sheep is being sheared and the person doing it is making a joke about the sheep's reaction to the process. The text on the meme adds to the humor by suggesting that the sheep might be reacting in a way that could be interpreted as defiance or resistance, which is a playful anthropomorphism of the animal.
# ------------------------------------------------------
# 01579.png
#  Yes, this meme is offensive. It uses a sensitive and controversial topic to make a political statement in an insensitive manner.
# ------------------------------------------------------
# 01436.png
#  No, this meme is not offensive. It's a humorous take on the situation where a frog is shooting a school shooter with an autistic kid watching, and it plays on the idea that the frog is taking action to protect the child. The humor comes from the absurdity of the situation and the unexpected twist in the story.
# ------------------------------------------------------
# 01475.png
#  Yes, this meme is offensive. It uses a historical figure and makes light of a serious event in history, which can be seen as disrespectful and insensitive.
# ------------------------------------------------------
# 01548.png
#  No, this meme is not offensive. It's a humorous take on the situation where someone is trying to get attention from another person who is preoccupied with something else. The text in the meme is a playful exaggeration of how one might feel when they are trying to communicate but being ignored.
# ------------------------------------------------------
# 01578.png
#  No, this image is not an offensive meme. It appears to be a humorous or satirical take on the idea of monkeys being associated with seafood, using a photo of people in water with a caption that plays on the word "monkey" and the concept of seafood. The humor seems to stem from the juxtaposition of the image with the text, which is meant to be funny or ironic.
# ------------------------------------------------------
# 01468.png
#  No, this meme is not offensive. It's a humorous take on the situation in Syria, using a relatable scenario of a child playing with toilet paper to make a point about the impact of explosions on everyday life.
# ------------------------------------------------------
# 01245.png
#  No, the meme is not offensive. It features a child in a military-style uniform holding a toy gun and smiling at the camera. The text on the meme reads, "And that was the last nativity play in my son was invited to take part in." This is a humorous commentary on the situation where the child's participation in a nativity play was canceled due to concerns about the presence of toy guns.
# ------------------------------------------------------
# 01452.png
#  No.
# ------------------------------------------------------
# 01547.png
#  Yes, this meme is offensive. It uses a stereotype to make a joke that is not respectful or accurate.
# ------------------------------------------------------
# 01456.png
#  Yes, this meme is offensive. It uses imagery from historical events and combines it with modern political commentary in a way that trivializes the seriousness of those events and makes light of them for comedic effect. This kind of humor can be seen as disrespectful to those who suffered during these historical periods.
# ------------------------------------------------------
# 01325.png
#  No, the meme is not offensive. It's a humorous take on the World Cup team's performance and the goal-scoring abilities of one player in particular.
# ------------------------------------------------------
# 01389.png
#  No, the meme is not offensive. It features a person holding a cat with a caption that reads "Confession: Every Sunday around brunch time I take my cat to the mall and make people take pictures of us." The image is meant to be humorous and does not contain any offensive content.
# ------------------------------------------------------
# 01469.png
#  Yes, this meme is offensive. It uses a sensitive topic to make a joke that is not appropriate or respectful.
# ------------------------------------------------------
# 01526.png
#  No.
# ------------------------------------------------------
# 01395.png
#  Yes, this meme is offensive. It uses a stereotype to make a joke that is not respectful or appropriate.
# ------------------------------------------------------
# 01576.png
#  No, the meme is not offensive. It's a humorous take on a situation where someone might be seeking help or advice from their ex-partner.
# ------------------------------------------------------
# 01497.png
#  No, the meme is not offensive. It shows a man holding a child and includes text that reads "Now back to the Islamic classic married to children." The meme appears to be making a humorous commentary on a situation or event related to Islam and marriage, but it does not contain any offensive language or imagery.
# ------------------------------------------------------
# 01476.png
#  No, this is not an offensive meme. It appears to be a humorous image with a caption that plays on the idea of confidence in one's appearance or abilities.
# ------------------------------------------------------
# 01359.png
#  Yes, this meme is offensive. It contains a series of images that are intended to be humorous but rely on racial stereotypes and derogatory language. The content of the meme is not appropriate for public sharing or display due to its offensive nature.
# ------------------------------------------------------
# 01529.png
#  Yes, this meme is offensive. It uses a sensitive topic to make a joke that is not appropriate or respectful.
# ------------------------------------------------------
# 01643.png
#  Yes, this meme is offensive. It uses a racial stereotype to make a joke about a family situation.
# ------------------------------------------------------
# 01264.png
#  No, this meme is not offensive. It's a humorous take on the idea of someone being surprised by the size of a squirrel's nuts. The humor comes from the exaggerated reaction to an unexpectedly large object, which in this case is a squirrel's acorn stash.
# ------------------------------------------------------
# 01236.png
#  No, this meme is not offensive. It's a humorous comparison between the image of sheep and the photo of people at a strip club, with a caption that plays on the idea of being surprised or shocked by the contrast between the two scenes. The meme uses the juxtaposition of the two images to create a comedic effect.
# ------------------------------------------------------
# 01672.png
#  No.
# ------------------------------------------------------
# 01492.png
#  Yes, this meme is offensive. It uses a person's image without their consent and makes a joke that is disrespectful to people with disabilities.
# ------------------------------------------------------
# 01524.png
#  No, this meme is not offensive. It's a humorous take on the idea of someone carrying a gun and being prepared for any situation. The text "when you catch your goat with another man" is a playful way to describe being ready for unexpected events or encounters.
# ------------------------------------------------------
# 01247.png
#  Yes, this meme is offensive. It uses a historical figure in a way that trivializes their actions and makes light of a serious issue.
# ------------------------------------------------------
# 01327.png
#  Yes, this meme is offensive. It uses a well-known character from the Batman series to make light of a serious and sensitive issue, which can be hurtful and disrespectful to those who have been affected by it.
# ------------------------------------------------------
# 01256.png
#  Yes
# ------------------------------------------------------
# 01295.png
#  Yes, this meme is offensive. It uses a sensitive and serious topic to make a joke that is not appropriate or respectful.
# ------------------------------------------------------
# 01348.png
#  No, this meme is not offensive. It's a humorous comparison between the appearance of sheep and people at a strip club, using a photo of sheep to create a joke about the attendees at the club. The meme is meant to be lighthearted and funny.
# ------------------------------------------------------
# 01483.png
#  No, the meme is not offensive. It's a humorous image that plays on the idea of someone feeling bored and looking for something to do, with the punchline being that they are going to a mosque. The humor comes from the juxtaposition of the person's boredom with the seriousness of visiting a place of worship.
# ------------------------------------------------------
# 01637.png
#  No, the meme is not offensive. It's a humorous take on the idea of needing to get away from something that is causing stress or inconvenience.
# ------------------------------------------------------
# 01293.png
#  Yes, this meme is offensive. It uses a sensitive and serious topic—the COVID-19 pandemic—to make a joke that is not appropriate or respectful.
# ------------------------------------------------------
# 01258.png
#  Yes, the meme is offensive.
# ------------------------------------------------------
# 01569.png
#  No, the meme is not offensive. It's a humorous take on a common situation where someone is trying to make a decision and another person is attempting to influence that decision by making a face or gesture. The text is meant to be funny and relatable for many people who have experienced similar situations with friends or family members.
# ------------------------------------------------------
# 01658.png
#  Yes, this meme is offensive. It uses a sensitive topic to make a joke that is not appropriate or respectful.
# ------------------------------------------------------
# 01439.png
#  No, the meme is not offensive. It's a humorous image featuring two animals with text that plays on the idea of a long and strong relationship, using the phrase "long and strong" in a literal sense to describe their physical attributes. The humor comes from the unexpected twist on the phrase.
# ------------------------------------------------------
# 01627.png
#  Yes, this meme is offensive. It uses a religious symbol in a disrespectful manner and makes light of a serious issue.
# ------------------------------------------------------
# 01284.png
#  Yes
# ------------------------------------------------------
# 01568.png
#  No, this is not an offensive meme. It appears to be a political statement or question, rather than a joke or humorous image.
# ------------------------------------------------------
# 01274.png
#  No, the meme is not offensive. It's a humorous take on a situation where someone might be trying to make a point or argument but it's being ignored or dismissed by another person. The text "but when padosi sees you" adds a layer of humor by suggesting that the person who is being ignored has a reputation for being aggressive, which is why they are not being taken seriously.
# ------------------------------------------------------
# 01465.png
#  Yes, this meme is offensive. It uses a sensitive and tragic event as a basis for humor, which is in poor taste.
# ------------------------------------------------------
# 01364.png
#  No, this image is not an offensive meme. It appears to be a photograph of people in protective suits, possibly indicating a hazardous environment or a need for safety precautions. The text overlaying the image seems unrelated and does not contribute to any offensive content.
# ------------------------------------------------------
# 01653.png
#  Yes
# ------------------------------------------------------
# 01649.png
#  Yes, the meme appears to be offensive. It uses a derogatory term and makes light of a serious issue, which is not appropriate for public discourse.
# ------------------------------------------------------
# 01243.png
#  No, this meme is not offensive. It features a dog with a caption that humorously attributes human-like qualities to the animal, which is a common trope in internet culture for comedic effect. The meme does not contain any language or imagery that could be considered offensive.
# ------------------------------------------------------
# 01546.png
#  Yes, this meme is offensive. It uses a historical figure in a way that trivializes and distorts their significance for political purposes, which can be seen as disrespectful and inappropriate.
# ------------------------------------------------------
# 01598.png
#  No.
# ------------------------------------------------------
# 01269.png
#  No, this meme is not offensive. It features a Kermit the Frog plush toy with a caption that reads "Kermit the frog definitely not a muslim." The image is meant to be humorous and is not intended to offend anyone.
# ------------------------------------------------------
# 01642.png
#  Yes
# ------------------------------------------------------
# 01324.png
#  No.
# ------------------------------------------------------
# 01459.png
#  No, this meme is not offensive. It's a humorous take on the idea of trusting someone who is an "all terrorist." The humor comes from the juxtaposition of the person being trusted with the absurdity of their profession and the fact that they are all terrorists.
# ------------------------------------------------------
# 01268.png
#  No, the meme is not offensive. It shows a family embracing and includes a caption that reflects their bonding time. The text "father and daughter bonding time is the best" is a positive statement about the value of spending quality time with loved ones.
# ------------------------------------------------------
# 01382.png
#  No, this meme is not offensive. It's a humorous take on the idea of making a choice about abortion, using a chalkboard with "abortion" written on it as a visual metaphor for the topic. The text "my body my choice" is a common slogan used by pro-choice advocates to express their view that individuals should have the right to make decisions about their own bodies and reproductive health.
# ------------------------------------------------------
# 01392.png
#  No, the meme is not offensive. It features a young girl talking on her cell phone with a caption that reads "hello jesus" and "thanks for making a way." The meme is meant to be humorous by playing on the idea of someone being grateful for having a means of communication, which in this context is a cell phone. It does not contain any offensive language or imagery.
# ------------------------------------------------------
# 01423.png
#  No, the meme is not offensive. It's a humorous take on a couple enjoying their time together in bed.
# ------------------------------------------------------
# 01498.png
#  Yes, this meme is offensive. It uses a sensitive topic to make a joke that is not appropriate or respectful.
# ------------------------------------------------------
# 01276.png
#  No, the meme is not offensive. It's a play on words with a humorous intent.
# ------------------------------------------------------
# 01329.png
#  No, this image is not an offensive meme. It features two men in cowboy hats holding guns and appears to be a humorous take on the stereotype of cowboys. The text "saddle up motherfuckers" is a playful phrase that does not contain any offensive language or imagery.
# ------------------------------------------------------
# 01275.png
#  Yes, this meme is offensive.
# ------------------------------------------------------
# 01564.png
#  Yes
# ------------------------------------------------------
# 01589.png
#  Yes, this meme is offensive. It uses a derogatory term to make a joke about a public figure, which can be hurtful and inappropriate.
# ------------------------------------------------------
# 01379.png
#  Yes, this meme is offensive. It uses a stereotype to make a point about the situation in Africa, which is not appropriate or respectful.
# ------------------------------------------------------
# 01472.png
#  Yes, this meme is offensive.

# %%
list_of_image_names
# Out:
# ['01527.png',
#  '01487.png',
#  '01349.png',
#  '01467.png',
#  '01235.png',
#  '01634.png',
#  '01579.png',
#  '01436.png',
#  '01475.png',
#  '01548.png',
#  '01578.png',
#  '01468.png',
#  '01245.png',
#  '01452.png',
#  '01547.png',
#  '01456.png',
#  '01325.png',
#  '01389.png',
#  '01469.png',
#  '01526.png',
#  '01395.png',
#  '01576.png',
#  '01497.png',
#  '01476.png',
#  '01359.png',
#  '01529.png',
#  '01643.png',
#  '01264.png',
#  '01236.png',
#  '01672.png',
#  '01492.png',
#  '01524.png',
#  '01247.png',
#  '01327.png',
#  '01256.png',
#  '01295.png',
#  '01348.png',
#  '01483.png',
#  '01637.png',
#  '01293.png',
#  '01258.png',
#  '01569.png',
#  '01658.png',
#  '01439.png',
#  '01627.png',
#  '01284.png',
#  '01568.png',
#  '01274.png',
#  '01465.png',
#  '01364.png',
#  '01653.png',
#  '01649.png',
#  '01243.png',
#  '01546.png',
#  '01598.png',
#  '01269.png',
#  '01642.png',
#  '01324.png',
#  '01459.png',
#  '01268.png',
#  '01382.png',
#  '01392.png',
#  '01423.png',
#  '01498.png',
#  '01276.png',
#  '01329.png',
#  '01275.png',
#  '01564.png',
#  '01589.png',
#  '01379.png',
#  '01472.png']
