# %%
import ollama 
import os

# %%
images_path = '../datasets/ignore_dir/hateful_memes/img/'

list_of_image_names = os.listdir(images_path)

# %%
list_of_models = ['llava:7b', 
                  'llava:13b',
                  'llava:34b',
                  'llava-llama3',
                  'bakllava',
                  'moondream',
                  'minicpm-v',
                  'llava-phi3']

# %%
root_path = '/home/macula/SMATousi/CVPR/ViGIR_CVPR_LLM/datasets/ignore_dir/hateful_memes/img'

options= {  # new
            "seed": 123,
            "temperature": 0,
            "num_ctx": 2048, # must be set, otherwise slightly random output
        }
    
for image_name in list_of_image_names:
    
    image_path = os.path.join(root_path, image_name)
    
#     prompt = "Is this somehow an offensive meme? Please answer with YES or NO. DO NOT mention the reason: "
#     prompt = "Is this somehow an offensive meme? describe the reason: "
    prompt = "describe this image: "
    
    response = ollama.generate(model='llava-phi3', prompt=prompt, images=[image_path], options=options)
    
#     response = ollama.chat(model='llava:34b', messages=[
#       {
#         'role': 'user',
#         'content': prompt,
#       }, 
#     ], options= {  # new
#             "seed": 123,
#             "temperature": 0,
#             "num_ctx": 2048, # must be set, otherwise slightly random output
#         })
    # print(response)
#     print(prompt)
    print("------------------------------------------------------")
    print(image_name)
    print(response['response'])
    
#     break
# Out:
# ------------------------------------------------------
# 01527.png
# The image captures a moment of camaraderie and support between two individuals on a road. The person in the foreground, clad in black shorts, extends their hand to assist another individual who is wearing white pants. This gesture suggests a sense of teamwork or friendship.
#
# The background reveals an open road with trees lining its sides, suggesting a serene and peaceful setting. The sun casts long shadows on the ground, indicating that it might be either early morning or late afternoon.
#
# Overlaying this scene is a text in bold white letters that reads "Oh no I can't run anymore". This phrase adds an element of humor to the image, suggesting that despite their best efforts, they are unable to continue running due to exhaustion or perhaps some physical limitation. The overall composition of the image tells a story of companionship and resilience in the face of challenges.
# ...

# %%
list_of_image_names
# Out:
# ['01527.png',
#  '01487.png',
#  '01349.png',
#  '01467.png',
#  '01235.png',
#  '01634.png',
#  '01579.png',
#  '01436.png',
#  '01475.png',
#  '01548.png',
#  '01578.png',
#  '01468.png',
#  '01245.png',
#  '01452.png',
#  '01547.png',
#  '01456.png',
#  '01325.png',
#  '01389.png',
#  '01469.png',
#  '01526.png',
#  '01395.png',
#  '01576.png',
#  '01497.png',
#  '01476.png',
#  '01359.png',
#  '01529.png',
#  '01643.png',
#  '01264.png',
#  '01236.png',
#  '01672.png',
#  '01492.png',
#  '01524.png',
#  '01247.png',
#  '01327.png',
#  '01256.png',
#  '01295.png',
#  '01348.png',
#  '01483.png',
#  '01637.png',
#  '01293.png',
#  '01258.png',
#  '01569.png',
#  '01658.png',
#  '01439.png',
#  '01627.png',
#  '01284.png',
#  '01568.png',
#  '01274.png',
#  '01465.png',
#  '01364.png',
#  '01653.png',
#  '01649.png',
#  '01243.png',
#  '01546.png',
#  '01598.png',
#  '01269.png',
#  '01642.png',
#  '01324.png',
#  '01459.png',
#  '01268.png',
#  '01382.png',
#  '01392.png',
# ...
